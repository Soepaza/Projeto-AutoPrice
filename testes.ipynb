# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
produtos = pd.read_excel('buscas.xlsx')
lista_nomes = produtos['Nome'].replace(' ', '', regex=True).to_list()
print(lista_nomes)


for nome in lista_nomes:
    url = f'https://www.buscape.com.br/search?q={nome}'
    print(url)
# Out:
# ['iphone 12 64gb', 'rtx 3060']
# https://www.buscape.com.br/search?q=iphone 12 64gb
# https://www.buscape.com.br/search?q=rtx 3060
